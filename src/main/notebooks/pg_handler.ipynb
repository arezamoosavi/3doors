# %%
import psycopg2

# %%
con = psycopg2.connect(
    host="postgres",
    database="atmdb",
    user="admin",
    password="admin")

# %%
cur = con.cursor()
cur.execute("SELECT * from atm_data;")
rows = cur.fetchall()

for row in rows:
    print(row)
    
# con.close()
# Out:
# ('{"ATM_Name": "Big Street ATM"', None, None, None, None, None, None, ' "Amount_withdrawn_Other_Card": "82100"', ' "Weekday": "Saturday"', ' "Festival_Religion": "H"', ' "Working_Day": "H"')
# ('{"ATM_Name": "Mount Road ATM"', None, None, None, None, None, None, ' "Amount_withdrawn_Other_Card": "497000"', ' "Weekday": "Saturday"', ' "Festival_Religion": "C"', ' "Working_Day": "H"')
# ('{"ATM_Name": "Airport ATM"', None, None, None, None, None, None, ' "Amount_withdrawn_Other_Card": "155700"', ' "Weekday": "Saturday"', ' "Festival_Religion": "C"', ' "Working_Day": "H"')
# ('{"ATM_Name": "KK Nagar ATM"', None, None, None, None, None, None, ' "Amount_withdrawn_Other_Card": "412700"', ' "Weekday": "Saturday"', ' "Festival_Religion": "C"', ' "Working_Day": "H"')
# ('{"ATM_Name": "Christ College ATM"', None, None, None, None, None, None, ' "Amount_withdrawn_Other_Card": "139500"', ' "Weekday": "Saturday"', ' "Festival_Religion": "C"', ' "Working_Day": "H"')
# ...
